# %% [markdown]
# #### Read file to extract Revenue and Product Quantity.

# %%
import pyautogui
import time
import pandas

path = r"C:\Users\chrys\Downloads\Vendas - Dez.xlsx"
table = pandas.read_excel(path)
display(table)

# %% [markdown]
# #### Get the position of the item you want to click.

# %%
print(pyautogui.position())
time.sleep(4)
# Out:
# Point(x=247, y=221)
